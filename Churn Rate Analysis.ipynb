# %% [markdown]
# # Churn Rate Analysis
# Esse notebook contempla a análise exploratória sobre a retenção de profissionais de medicina e enfermagem nas regiões de saúde com base em dados do CNES-PF.

# %% [markdown]
# ## Carregar bibliotecas

# %%
# Reload automático no Jupyter Notebook
# %reload_ext autoreload
# %autoreload 2

import traceback
import warnings
from dados import *
from tratamentos import *
from modelagem import *
from visualizacoes import *
from avaliacao import *

# %% [markdown]
# ## Configurar bibliotecas

# %%
# Remover limite de exibição de linhas e colunas do pandas
pd.set_option('max_rows', 9999)
pd.set_option('max_columns', 9999)

# Evitar notações científicas no pandas
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Evitar warnings sobre perfomance no pandas
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# ## Obter dados

# %%
df = obter_dados('profissionais.sql')
df.head()
# Out:
#   COMPETEN CODUFMUN   categoria                    CPF_PROF
# 0   201901   120020  Enfermeiro  <83><80>~{{<81>}}<81><83>
# 1   201901   120020      Médico     {<84><81>}}<81>{<82>
# 2   201901   120040  Enfermeiro     |~<83><82><83>{}}<82>}
# 3   201901   120040      Médico     {|<82><82><84>|}|~<84>
# 4   201901   120040      Médico        }}{{<80>{}<81><83>

# %%
geo = obter_dados('municipios.sql')
geo.head()
# Out:
#          uf uf_sigla cod_regsaud    regiao_saude  cod_municipiodv  \
# 0  Rondônia       RO       11001  Vale do Jamari          1100452
# 1  Rondônia       RO       11003         Central          1100114
# 2  Rondônia       RO       11003         Central          1100254
# 3  Rondônia       RO       11004  Madeira-Mamoré          1100205
# 4  Rondônia       RO       11004  Madeira-Mamoré          1100809
#
#   cod_municipio           municipio
# 0        110045             Buritis
# 1        110011                Jaru
# 2        110025   Presidente Médici
# 3        110020         Porto Velho
# 4        110080  Candeias do Jamari

# %%
# Realizar o join dos dados do CNES com tabela de municipios
df = df.merge(geo, left_on=['CODUFMUN'], right_on=['cod_municipio'])
df.head()
# Out:
#   COMPETEN CODUFMUN   categoria                             CPF_PROF    uf  \
# 0   201901   120020  Enfermeiro           <83><80>~{{<81>}}<81><83>  Acre
# 1   201901   120020      Médico              {<84><81>}}<81>{<82>  Acre
# 2   201901   120020      Médico                 ~<80>{<82>{<83>}{{  Acre
# 3   201901   120020  Enfermeiro  <80><84><82>|<82><84>~<84>}<81><83>  Acre
# 4   201901   120020  Enfermeiro              <81><84>{}<82>}|<80>  Acre
#
#   uf_sigla cod_regsaud             regiao_saude  cod_municipiodv  \
# 0       AC       12003  Juruá e Tarauacá/Envira          1200203
# 1       AC       12003  Juruá e Tarauacá/Envira          1200203
# 2       AC       12003  Juruá e Tarauacá/Envira          1200203
# 3       AC       12003  Juruá e Tarauacá/Envira          1200203
# 4       AC       12003  Juruá e Tarauacá/Envira          1200203
#
#   cod_municipio        municipio
# 0        120020  Cruzeiro do Sul
# 1        120020  Cruzeiro do Sul
# 2        120020  Cruzeiro do Sul
# 3        120020  Cruzeiro do Sul
# 4        120020  Cruzeiro do Sul

# %% [markdown]
# ## Processar os dados e criar os gráficos e arquivos CSV de retenção por região de saúde

# %%
# Realizar processamento para cada categoria profissional
for categoria in df['categoria'].unique():
    df_categoria = df.loc[df['categoria'] == categoria].copy()

    # Criar listas para salvar dados a serem exportados
    estatisticas_curvas = []
    triangulos = []
    mapes = []
    retencao_ano = []
    retencao_geral = []

    # Realizar o processamento separado para cada região de saúde
    i=0
    for regiao_saude in df['cod_regsaud'].unique():
        try:
            print(f'Processando {regiao_saude} - {i+1}/{len(df["cod_regsaud"].unique())}')
            df_categoria_regiao = df_categoria.loc[df_categoria['cod_regsaud'] == regiao_saude].copy()

            # Agregar os dados por cohorts
            cohort_pivot, cohort_sizes = gerar_triangulo_agregado(df_categoria_regiao.copy())

            # Obter o modelo chainladder
            cl_model = treinar_chainladder(cohort_pivot.copy())

            # Calcular profissionais restantes em cada período do cohort
            restantes = calcular_restantes(cl_model, cohort_pivot.copy())

            # Realizar a divisão de cada célula da tabela pivotada pelo tamanho do grupo para deixar em percentual
            percentual_restantes = calcular_percentual_restantes(restantes, cohort_sizes)

            # Calcular retenção anual (últimos 5 anos) por região de saúde
            retencao_anual = calcular_retencao_ano_regiao(percentual_restantes.copy(), regiao_saude)
            retencao_ano.append(retencao_anual)

            # Calcular retenção geral (média de todo o triangulo)
            retencao_geral.append(pd.DataFrame({'regiao_saude': [regiao_saude], 'retencao_geral': [cohort_pivot.divide(cohort_sizes, axis = 0).unstack().mean()]}))

            # Salvar dados do triangulo para exportar em csv
            cohort_pivot['cod_regsaud'] = regiao_saude
            triangulos.append(cohort_pivot.copy())
            cohort_pivot.drop(['cod_regsaud'], axis=1, inplace=True)

            # Criar features para ML sobre caracteristicas estatisticas da curva
            obs = gerar_ml_features(cohort_pivot, regiao_saude)
            estatisticas_curvas.append(obs)

            # Calcular mape
            mape = calcular_mape(cl_model).stack().mean()
            mapes.append(pd.DataFrame({'cod_regsaud': [regiao_saude], 'mape': [mape]}))

            # Gerar gráficos
            nome_regiao = df_categoria_regiao["regiao_saude"].values[0]
            uf_regiao = df_categoria_regiao["uf_sigla"].values[0]
            gerar_graficos(restantes.copy(), percentual_restantes.copy(), cl_model, f'Região de Saúde {nome_regiao} - {uf_regiao}', f'{categoria}{regiao_saude}')

            i+=1
        except Exception as e:
            print(f'Erro na região de saúde {regiao_saude}: {e}')
            # print(traceback.format_exc())
            continue


    # Exportar dados em CSV
    pd.concat(estatisticas_curvas).to_csv(f'csvs/{categoria}_estatisticas_curvas.csv', sep=';')
    pd.concat(triangulos).to_csv(f'csvs/{categoria}_triangulos.csv', sep=';')
    pd.concat(mapes).to_csv(f'csvs/{categoria}_mapes.csv', sep=';')
    pd.concat(retencao_ano).to_csv(f'csvs/{categoria}_retencao_ano.csv', sep=';')
    pd.concat(retencao_geral).to_csv(f'csvs/{categoria}_retencao_geral.csv', sep=';')
# Out:
# Processando 12003 - 1/450
# Processando 12002 - 2/450
# Processando 12001 - 3/450
# Processando 27007 - 4/450
# Processando 27008 - 5/450
# Processando 27010 - 6/450
# Erro na região de saúde 27010: '[180] not found in axis'
# Processando 27001 - 6/450
# Processando 31016 - 115/450
# Processando 31017 - 116/450
# Processando 31034 - 117/450
# Processando 31048 - 118/450
# Processando 31003 - 119/450
# Processando 31072 - 120/450
# Processando 31027 - 121/450
# Processando 31042 - 122/450
# Processando 31088 - 123/450
# Processando 31086 - 124/450
# Processando 31004 - 125/450
# Processando 31044 - 126/450
# Processando 31007 - 127/450
# Processando 31078 - 128/450
# Processando 31079 - 129/450
# Processando 31018 - 130/450
# Processando 31019 - 131/450
# Processando 31035 - 132/450
# Processando 31091 - 133/450
# Processando 31026 - 134/450
# Processando 31012 - 135/450
# Processando 31052 - 136/450
# Processando 31097 - 137/450
# Processando 31071 - 138/450
# Processando 31036 - 139/450
# Processando 31020 - 140/450
# Processando 31002 - 141/450
# Processando 31049 - 142/450
# Processando 31032 - 143/450
# Processando 31024 - 144/450
# Processando 31037 - 145/450
# Processando 31022 - 146/450
# Processando 31053 - 147/450
# Processando 31031 - 148/450
# Processando 31073 - 149/450
# Processando 31023 - 150/450
# Processando 31057 - 151/450
# Processando 31025 - 152/450
# Processando 31090 - 153/450
# Processando 31015 - 154/450
# Processando 31099 - 155/450
# Processando 31059 - 156/450
# Processando 31038 - 157/450
# Processando 31047 - 158/450
# Processando 31082 - 159/450
# Processando 31074 - 160/450
# Processando 31009 - 161/450
# Processando 31084 - 162/450
# Processando 31045 - 163/450
# Processando 31066 - 164/450
# Processando 31058 - 165/450
# Processando 31080 - 166/450
# Processando 31055 - 167/450
# Processando 31060 - 168/450
# Processando 31040 - 169/450
# Processando 31094 - 170/450
# Processando 31011 - 171/450
# Processando 31050 - 172/450
# Erro na região de saúde 31050: '[180] not found in axis'
# Processando 31085 - 172/450
# Processando 31061 - 173/450
# Processando 31093 - 174/450
# Processando 31010 - 175/450
# Processando 51013 - 176/450
# Processando 51011 - 177/450
# Processando 51006 - 178/450
# Processando 51010 - 179/450
# Processando 51002 - 180/450
# Processando 51015 - 181/450
# Processando 51008 - 182/450
# Processando 51001 - 183/450
# Processando 51005 - 184/450
# Processando 51009 - 185/450
# C:\venvs\ufg_churn\lib\site-packages\chainladder\tails\base.py:120: RuntimeWarning: overflow encountered in exp
#   sigma_ = xp.exp(time_pd * reg.slope_ + reg.intercept_)
# Processando 51014 - 186/450
# Processando 51016 - 187/450
# Processando 51007 - 188/450
# Processando 51003 - 189/450
# Processando 25009 - 190/450
# Processando 25002 - 191/450
# Processando 25001 - 192/450
# Processando 25016 - 193/450
# Processando 25008 - 194/450
# Processando 25007 - 195/450
# Processando 25005 - 196/450
# Processando 25012 - 197/450
# Processando 25006 - 198/450
# Processando 25004 - 199/450
# Processando 25003 - 200/450
# Processando 25015 - 201/450
# Processando 25014 - 202/450
# Processando 25010 - 203/450
# Processando 26001 - 204/450
# Processando 26003 - 205/450
# Processando 26007 - 206/450
# Processando 26002 - 207/450
# Processando 26010 - 208/450
# Processando 26004 - 209/450
# Processando 26006 - 210/450
# Processando 26008 - 211/450
# Processando 26005 - 212/450
# Processando 26009 - 213/450
# Processando 26012 - 214/450
# Processando 26011 - 215/450
# Processando 22007 - 216/450
# C:\venvs\ufg_churn\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\venvs\ufg_churn\lib\site-packages\chainladder\core\slice.py:250: RuntimeWarning: invalid value encountered in multiply
#   obj.values = num_to_nan(obj.values * obj.get_array_module().array(key))
# Erro na região de saúde 22007: Length of values (15) does not match length of index (16)
# Processando 22003 - 216/450
# Processando 22004 - 217/450
# Processando 22005 - 218/450
# Processando 22001 - 219/450
# Processando 22011 - 220/450
# Processando 22008 - 221/450
# Processando 22002 - 222/450
# Processando 22009 - 223/450
# Processando 22006 - 224/450
# Processando 33001 - 225/450
# Processando 33002 - 226/450
# Processando 33004 - 227/450
# Processando 33005 - 228/450
# Processando 33007 - 229/450
# Processando 33009 - 230/450
# Processando 33008 - 231/450
# Processando 33003 - 232/450
# Processando 33006 - 233/450
# Processando 24004 - 234/450
# Processando 24003 - 235/450
# Processando 24001 - 236/450
# Processando 24002 - 237/450
# Processando 24007 - 238/450
# Processando 24006 - 239/450
# Processando 24008 - 240/450
# Erro na região de saúde 24008: '[180] not found in axis'
# Processando 24005 - 240/450
# Processando 11001 - 241/450
# Processando 11002 - 242/450
# Processando 11006 - 243/450
# Processando 11003 - 244/450
# Processando 11005 - 245/450
# Processando 11004 - 246/450
# Processando 14001 - 247/450
# Processando 14002 - 248/450
# Erro na região de saúde 14002: '[180] not found in axis'
# Processando 42011 - 248/450
# Processando 42014 - 249/450
# Processando 42016 - 250/450
# Processando 42004 - 251/450
# Processando 42005 - 252/450
# Processando 42007 - 253/450
# Processando 42006 - 254/450
# Processando 42002 - 255/450
# Processando 42010 - 256/450
# Processando 42015 - 257/450
# Processando 42017 - 258/450
# Processando 42003 - 259/450
# Processando 42008 - 260/450
# Processando 42013 - 261/450
# Processando 42012 - 262/450
# Processando 42001 - 263/450
# Processando 42009 - 264/450
# Processando 27004 - 265/450
# Processando 13005 - 266/450
# Processando 13003 - 267/450
# Processando 13007 - 268/450
# Processando 29008 - 269/450
# Processando 23007 - 270/450
# Processando 23006 - 271/450
# Processando 31068 - 272/450
# Processando 31083 - 273/450
# Processando 31077 - 274/450
# Processando 31089 - 275/450
# Processando 31028 - 276/450
# Processando 31051 - 277/450
# Processando 31046 - 278/450
# Processando 31081 - 279/450
# Erro na região de saúde 31081: '[180] not found in axis'
# Processando 25013 - 279/450
# Processando 25011 - 280/450
# Processando 22010 - 281/450
# Processando 11007 - 282/450
# Processando 31065 - 283/450
# Processando 31096 - 284/450
# Processando 51004 - 285/450
# Processando 51012 - 286/450
# Processando 31095 - 287/450
# Processando 31067 - 288/450
# Processando 31076 - 289/450
# Processando 31098 - 290/450
# Erro na região de saúde 31098: Length of values (14) does not match length of index (15)
# Processando 16001 - 290/450
# Processando 16003 - 291/450
# Processando 16002 - 292/450
# Erro na região de saúde 16002: '[180] not found in axis'
# Processando 53001 - 292/450
# Processando 50001 - 293/450
# Processando 50003 - 294/450
# Processando 50004 - 295/450
# Processando 50002 - 296/450
# Processando 23010 - 58/450
# Processando 23003 - 59/450
# Processando 23008 - 60/450
# Processando 23014 - 61/450
# Processando 23013 - 62/450
# Processando 23005 - 63/450
# Processando 52004 - 64/450
# Processando 52011 - 65/450
# Processando 52012 - 66/450
# Processando 52002 - 67/450
# Processando 52009 - 68/450
# Processando 52003 - 69/450
# Processando 52016 - 70/450
# Processando 52005 - 71/450
# Processando 52001 - 72/450
# Processando 52018 - 73/450
# Processando 52017 - 74/450
# Processando 52008 - 75/450
# Processando 52013 - 76/450
# Processando 52015 - 77/450
# Processando 52014 - 78/450
# Processando 52010 - 79/450
# Processando 52007 - 80/450
# Processando 52006 - 81/450
# C:\venvs\ufg_churn\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\venvs\ufg_churn\lib\site-packages\chainladder\core\slice.py:250: RuntimeWarning: invalid value encountered in multiply
#   obj.values = num_to_nan(obj.values * obj.get_array_module().array(key))
# Processando 21001 - 82/450
# Processando 21007 - 83/450
# Processando 21014 - 84/450
# Processando 21003 - 85/450
# Processando 21013 - 86/450
# Processando 21019 - 87/450
# Processando 21005 - 88/450
# Processando 21006 - 89/450
# Processando 21011 - 90/450
# Processando 21012 - 91/450
# Processando 21008 - 92/450
# Processando 21004 - 93/450
# Processando 21010 - 94/450
# Processando 21017 - 95/450
# Processando 21009 - 96/450
# Processando 21015 - 97/450
# Processando 21016 - 98/450
# Processando 21018 - 99/450
# Processando 21002 - 100/450
# Processando 31062 - 101/450
# Processando 31008 - 102/450
# Processando 31041 - 103/450
# Processando 31001 - 104/450
# Processando 31092 - 105/450
# Processando 31013 - 106/450
# Processando 31006 - 107/450
# Processando 31064 - 108/450
# Processando 31075 - 109/450
# Processando 31070 - 110/450
# Processando 31087 - 111/450
# Processando 31030 - 112/450
# Processando 31021 - 113/450
# Processando 31016 - 114/450
# Processando 31017 - 115/450
# Processando 31034 - 116/450
# Processando 31048 - 117/450
# Processando 31003 - 118/450
# Processando 31072 - 119/450
# Processando 31027 - 120/450
# Processando 31042 - 121/450
# Processando 31088 - 122/450
# Processando 31086 - 123/450
# Processando 31004 - 124/450
# Processando 31044 - 125/450
# Processando 31007 - 126/450
# Processando 31078 - 127/450
# Processando 31079 - 128/450
# Processando 31018 - 129/450
# Processando 31019 - 130/450
# Processando 31035 - 131/450
# Processando 31091 - 132/450
# Erro na região de saúde 31091: '[180] not found in axis'
# Processando 31026 - 132/450
# Processando 31012 - 133/450
# Processando 31052 - 134/450
# Processando 31097 - 135/450
# Processando 31071 - 136/450
# Processando 31036 - 137/450
# Processando 31020 - 138/450
# Erro na região de saúde 31020: '[180] not found in axis'
# Processando 31002 - 138/450
# Processando 31049 - 139/450
# Processando 31032 - 140/450
# Processando 31024 - 141/450
# Processando 31037 - 142/450
# Processando 31022 - 143/450
# Processando 31053 - 144/450
# Processando 31031 - 145/450
# Processando 31073 - 146/450
# Processando 31023 - 147/450
# Processando 31057 - 148/450
# Processando 31025 - 149/450
# Processando 31090 - 150/450
# Processando 31015 - 151/450
# Processando 31099 - 152/450
# Processando 42011 - 242/450
# Processando 42014 - 243/450
# Processando 42016 - 244/450
# Processando 42004 - 245/450
# Processando 42005 - 246/450
# Processando 42007 - 247/450
# Processando 42006 - 248/450
# Processando 42002 - 249/450
# Processando 42010 - 250/450
# Processando 42015 - 251/450
# Processando 42017 - 252/450
# Processando 42003 - 253/450
# Processando 42008 - 254/450
# Processando 42013 - 255/450
# Processando 42012 - 256/450
# Processando 42001 - 257/450
# Processando 42009 - 258/450
# Processando 27004 - 259/450
# Processando 13005 - 260/450
# Processando 13003 - 261/450
# Erro na região de saúde 13003: '[180] not found in axis'
# Processando 13007 - 261/450
# Processando 29008 - 262/450
# Processando 23007 - 263/450
# Processando 23006 - 264/450
# Processando 31068 - 265/450
# Processando 31083 - 266/450
# Erro na região de saúde 31083: '[180] not found in axis'
# Processando 31077 - 266/450
# Processando 31089 - 267/450
# Processando 31028 - 268/450
# Processando 31051 - 269/450
# Erro na região de saúde 31051: '[180] not found in axis'
# Processando 31046 - 269/450
# Processando 31081 - 270/450
# Processando 25013 - 271/450
# Processando 25011 - 272/450
# Erro na região de saúde 25011: '[180] not found in axis'
# Processando 22010 - 272/450
# Processando 11007 - 273/450
# Erro na região de saúde 11007: '[180] not found in axis'
# Processando 31065 - 273/450
# Processando 31096 - 274/450
# Processando 51004 - 275/450
# Processando 51012 - 276/450
# Processando 31095 - 277/450
# Processando 31067 - 278/450
# Processando 31076 - 279/450
# Processando 31098 - 280/450
# Processando 16001 - 281/450
# Processando 16003 - 282/450
# Processando 16002 - 283/450
# Processando 53001 - 284/450
# Processando 50001 - 285/450
# Processando 50003 - 286/450
# Processando 50004 - 287/450
# Processando 50002 - 288/450
# Processando 15011 - 289/450
# Processando 15003 - 290/450
# Processando 15002 - 291/450
# Processando 15012 - 292/450
# Processando 15006 - 293/450
# Processando 15009 - 294/450
# Processando 15004 - 295/450
# Processando 15008 - 296/450
# Processando 15013 - 297/450
# Erro na região de saúde 15013: Length of values (15) does not match length of index (16)
# C:\venvs\ufg_churn\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\venvs\ufg_churn\lib\site-packages\chainladder\core\slice.py:250: RuntimeWarning: invalid value encountered in multiply
#   obj.values = num_to_nan(obj.values * obj.get_array_module().array(key))
# Processando 15001 - 297/450
# Processando 15010 - 298/450
# Processando 15007 - 299/450
# Processando 41016 - 300/450
# Processando 41002 - 301/450
# Processando 41020 - 302/450
# Processando 41011 - 303/450
# Processando 41003 - 304/450
# Processando 41010 - 305/450
# Processando 41013 - 306/450
# Processando 41012 - 307/450
# Processando 41021 - 308/450
# Processando 41004 - 309/450
# Processando 41015 - 310/450
# Processando 41009 - 311/450
# Processando 41008 - 312/450
# Processando 41014 - 313/450
# Processando 41005 - 314/450
# Processando 41001 - 315/450
# Processando 41017 - 316/450
# Processando 41022 - 317/450
# Processando 41019 - 318/450
# Processando 41007 - 319/450
# Processando 41006 - 320/450
# Processando 41018 - 321/450
# Processando 43003 - 322/450
# Processando 43010 - 323/450
# Processando 43029 - 324/450
# Processando 43004 - 325/450
